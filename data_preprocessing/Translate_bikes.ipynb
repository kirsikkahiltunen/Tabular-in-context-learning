# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/EN_Bikes.csv")

# %%
df.head()
# Out:
#    Departure station id Departure station name  Return station id  \
# 0                    56           Luoteisväylä              541.0
# 1                   135        Velodrominrinne              148.0
# 2                   727              Ratsutori              711.0
# 3                   711           Kirjurinkuja              729.0
# 4                    43            Karhupuisto               16.0
#
#                      Return station name  Covered distance (m)  \
# 0  Aalto-yliopisto (M), Korkeakouluaukio                3683.0
# 1                    Juhana Herttuan tie                2726.0
# 2                           Kirjurinkuja                1025.0
# 3                       Leppävaaranaukio                 946.0
# 4                        Liisanpuistikko                1451.0
#
#    Duration (sec.)    Year  Month  Departure day  Departure hour  \
# 0              712  2019.0    6.0           19.0             8.0
# ...

# %%
df = df.rename(columns={"Departure station id": "Lähtöaseman id" , "Return station id": "Palautusaseman id", "Departure station name": "Lähtöaseman nimi", "Return station name": "Palautusaseman nimi", "Covered distance (m)": "Kuljettu matka (m)", "Duration (sec.)": "Kesto (sek.)", "Year": "Vuosi", "Month": "Kuukausi", "Departure day": "Lähtöpäivä", "Departure hour":"Lähtö tunti", "Departure min.": "Lähtö min.", "Departure sec.":"Lähtö sek.", "Return day": "Palautuspäivä", "Return hour":"Palautus tunti", "Return hour": "Palautustunti", "Return min.": "Palautus min.", "Return sec.": "Palautus sek."})

# %%
df.head()
# Out:
#    Lähtöaseman id Lähtöaseman nimi  Palautusaseman id  \
# 0              56     Luoteisväylä              541.0
# 1             135  Velodrominrinne              148.0
# 2             727        Ratsutori              711.0
# 3             711     Kirjurinkuja              729.0
# 4              43      Karhupuisto               16.0
#
#                      Palautusaseman nimi  Kuljettu matka (m)  Kesto (sek.)  \
# 0  Aalto-yliopisto (M), Korkeakouluaukio              3683.0           712
# 1                    Juhana Herttuan tie              2726.0           727
# 2                           Kirjurinkuja              1025.0           292
# 3                       Leppävaaranaukio               946.0           278
# 4                        Liisanpuistikko              1451.0           517
#
#     Vuosi  Kuukausi  Lähtöpäivä  Lähtö tunti  Lähtö min.  Lähtö sek.  \
# 0  2019.0       6.0        19.0          8.0        49.0        15.0
# ...

# %%
df.to_csv("data/FI_Bikes.csv", index=False)
